# %% [markdown]
# ## HADISST

# %% [raw]
# %%bash
# file='/home/cccr/roxy/panini/JGRJD_PHD_PART_I/DATA/sst/HADISST/HadISST_sst.nc'
#
# cdo remapbil,r360X180 ${file} had.nc
# cdo sellonlatbox,0,360,-60,60 -selname,sst had.nc hadisst.nc
# cdo ymonmean -selyear,1905/2015 hadisst.nc clim_sst.nc
# cdo sub hadisst.nc clim_sst.nc sst_mon_anomalies_1870-2019.nc
#
# rm hadisst.nc clim_sst.nc  had.nc
#
#
# for i in $(seq 1905 1 2014)
# do
# l=$((i + 1))
# cdo selmon,11,12 -selyear,$i sst_mon_anomalies_1870-2019.nc tempx1.nc
# cdo selmon,1,2,3,4 -selyear,$l sst_mon_anomalies_1870-2019.nc tempy1.nc
#
#
# cdo mergetime tempx1.nc tempy1.nc jgr1.nc
#
# cdo timmean jgr1.nc mean1_$l.nc
#
# # cdo mergetime mean*.nc mjo_mean$l.nc
#
# rm temp*.nc
# rm jgr*.nc
#
# echo $NUM
#
# done
#
# cdo mergetime mean1*.nc sst_raw_nov_apr_1905-2015_hadisst.nc
#
# rm mean*.nc
# rm sst_mon_anomalies_1870-2019.nc

# %% [markdown]
# ## ERSSTV5

# %% [raw]
# %%bash
# file='/home/cccr/roxy/panini/JGRJD_PHD_PART_I/DATA/sst/ERSST/ERSSTV5.sst.monmean.nc'
#
# cdo selname,sst ${file} ersst1.nc
# cdo sellonlatbox,0,360,-60,60 ersst1.nc ersst.nc
# cdo ymonmean -selyear,1905/2015 ersst.nc clim_sst.nc
# cdo sub ersst.nc clim_sst.nc sst_mon_anomalies_1870-2019.nc
#
# rm ersst.nc clim_sst.nc ersst1.nc
#
#
# for i in $(seq 1905 1 2014)
# do
# l=$((i + 1))
# cdo selmon,11,12 -selyear,$i sst_mon_anomalies_1870-2019.nc tempx1.nc
# cdo selmon,1,2,3,4 -selyear,$l sst_mon_anomalies_1870-2019.nc tempy1.nc
#
#
# cdo mergetime tempx1.nc tempy1.nc jgr1.nc
#
# cdo timmean jgr1.nc mean1_$l.nc
#
# # cdo mergetime mean*.nc mjo_mean$l.nc
#
# rm temp*.nc
# rm jgr*.nc
#
# echo $NUM
#
# done
#
# cdo mergetime mean1*.nc sst_raw_nov_apr_1905-2015_ersst5.nc
#
# rm mean*.nc
# rm sst_mon_anomalies_1870-2019.nc

# %% [markdown]
# ## skin Temperature GISS

# %% [raw]
# %%bash
# file='/home/cccr/roxy/panini/JGRJD_PHD_PART_I/DATA/skin_temperature/GISS/air.2x2.250.mon.anom.comb.nc'
#
# cdo remapbil,r360X181 ${file} had.nc
# cdo selname,air had.nc hadisst.nc
# cdo ymonmean -selyear,1905/2015 hadisst.nc clim_sst.nc
# cdo sub hadisst.nc clim_sst.nc skt_mon_anomalies_1870-2019.nc
#
# rm hadisst.nc clim_sst.nc  had.nc
#
#
# for i in $(seq 1905 1 2014)
# do
# l=$((i + 1))
# cdo selyear,$i skt_mon_anomalies_1870-2019.nc tempx1.nc
# cdo selmon,11,12 tempx1.nc tempx11.nc
# cdo selyear,$l skt_mon_anomalies_1870-2019.nc tempy1.nc
# cdo selmon,1,2,3,4 tempy1.nc tempy11.nc
#
# cdo mergetime tempx11.nc tempy11.nc jgr1.nc
#
# cdo timmean jgr1.nc mean1_$l.nc
#
# # cdo mergetime mean*.nc mjo_mean$l.nc
#
# rm temp*.nc
# rm jgr*.nc
#
# echo $NUM
#
# done
#
# cdo mergetime mean1*.nc skt_raw_nov_apr_1905-2015_giss.nc
#
# rm mean*.nc
# rm skt_mon_anomalies_1870-2019.nc

# %% [markdown]
# ## skin temperature 20CRV3

# %% [raw]
# %%bash
# file='/home/cccr/roxy/panini/JGRJD_PHD_PART_I/DATA/skin_temperature/20crV3/skt.mon.mean.nc'
#
# cdo selname,skt ${file} hadisst.nc
# cdo ymonmean -selyear,1905/2015 hadisst.nc clim_sst.nc
# cdo sub hadisst.nc clim_sst.nc skt_mon_anomalies_1870-2019.nc
#
# rm hadisst.nc clim_sst.nc  had.nc
#
#
# for i in $(seq 1905 1 2014)
# do
# l=$((i + 1))
# cdo selyear,$i skt_mon_anomalies_1870-2019.nc tempx1.nc
# cdo selmon,11,12 tempx1.nc tempx11.nc
# cdo selyear,$l skt_mon_anomalies_1870-2019.nc tempy1.nc
# cdo selmon,1,2,3,4 tempy1.nc tempy11.nc
#
# cdo mergetime tempx11.nc tempy11.nc jgr1.nc
#
# cdo timmean jgr1.nc mean1_$l.nc
#
# # cdo mergetime mean*.nc mjo_mean$l.nc
#
# rm temp*.nc
# rm jgr*.nc
#
# echo $NUM
#
# done
#
# cdo mergetime mean1*.nc skt_raw_nov_apr_1905-2015_20CRv3.nc
#
# rm mean*.nc
# rm skt_mon_anomalies_1870-2019.nc

# %% [markdown]
# ## CRU precipitation

# %% [raw]
# file = '/home/cccr/roxy/panini/JGRJD_PHD_PART_I/DATA/precip/CRU/cru_ts4.03.1901.2018.pre.dat.nc'
# cdo selname,pre ${file} hadisst.nc
# cdo ymonmean -selyear,1905/2015 hadisst.nc clim_sst.nc
# cdo sub hadisst.nc clim_sst.nc skt_mon_anomalies_1870-2019.nc
#
# rm hadisst.nc clim_sst.nc  had.nc
#
#
# for i in $(seq 1905 1 2014)
# do
# l=$((i + 1))
# cdo selyear,$i skt_mon_anomalies_1870-2019.nc tempx1.nc
# cdo selmon,11,12 tempx1.nc tempx11.nc
# cdo selyear,$l skt_mon_anomalies_1870-2019.nc tempy1.nc
# cdo selmon,1,2,3,4 tempy1.nc tempy11.nc
#
# cdo mergetime tempx11.nc tempy11.nc jgr1.nc
#
# cdo timmean jgr1.nc mean1_$l.nc
#
# # cdo mergetime mean*.nc mjo_mean$l.nc
#
# rm temp*.nc
# rm jgr*.nc
#
# echo $NUM
#
# done
#
# cdo mergetime mean1*.nc precip_raw_nov_apr_1905-2015_cru.nc
#
# rm mean*.nc
# rm skt_mon_anomalies_1870-2019.nc

# %% [markdown]
# ## GPCC

# %% [raw]
# file='/home/cccr/roxy/panini/JGRJD_PHD_PART_I/DATA/precip/GPCC/GPCC.precip.mon.total.v2018.nc'
# cdo selname,precip ${file} hadisst.nc
# cdo ymonmean -selyear,1905/2015 hadisst.nc clim_sst.nc
# cdo sub hadisst.nc clim_sst.nc skt_mon_anomalies_1870-2019.nc
#
# rm hadisst.nc clim_sst.nc  had.nc
#
#
# for i in $(seq 1905 1 2014)
# do
# l=$((i + 1))
# cdo selyear,$i skt_mon_anomalies_1870-2019.nc tempx1.nc
# cdo selmon,11,12 tempx1.nc tempx11.nc
# cdo selyear,$l skt_mon_anomalies_1870-2019.nc tempy1.nc
# cdo selmon,1,2,3,4 tempy1.nc tempy11.nc
#
# cdo mergetime tempx11.nc tempy11.nc jgr1.nc
#
# cdo timmean jgr1.nc mean1_$l.nc
#
# # cdo mergetime mean*.nc mjo_mean$l.nc
#
# rm temp*.nc
# rm jgr*.nc
#
# echo $NUM
#
# done
#
# cdo mergetime mean1*.nc precip_raw_nov_apr_1905-2015_gpcc.nc
#
# rm mean*.nc
# rm skt_mon_anomalies_1870-2019.nc

# %% [markdown]
# ## 20CRV3

# %% [raw]
# file='/home/cccr/roxy/panini/JGRJD_PHD_PART_I/DATA/precip/20_CR/prate.mon.mean_20CR_V3.nc'
# cdo selname,prate ${file} hadisst.nc
# cdo ymonmean -selyear,1905/2015 hadisst.nc clim_sst.nc
# cdo sub hadisst.nc clim_sst.nc skt_mon_anomalies_1870-2019.nc
#
# rm hadisst.nc clim_sst.nc  had.nc
#
#
# for i in $(seq 1905 1 2014)
# do
# l=$((i + 1))
# cdo selyear,$i skt_mon_anomalies_1870-2019.nc tempx1.nc
# cdo selmon,11,12 tempx1.nc tempx11.nc
# cdo selyear,$l skt_mon_anomalies_1870-2019.nc tempy1.nc
# cdo selmon,1,2,3,4 tempy1.nc tempy11.nc
#
# cdo mergetime tempx11.nc tempy11.nc jgr1.nc
#
# cdo timmean jgr1.nc mean1_$l.nc
#
# # cdo mergetime mean*.nc mjo_mean$l.nc
#
# rm temp*.nc
# rm jgr*.nc
#
# echo $NUM
#
# done
#
# cdo mergetime mean1*.nc precip_raw_nov_apr_1905-2015_20CRV3.nc
#
# rm mean*.nc
# rm skt_mon_anomalies_1870-2019.nc

# %% [markdown]
# ## MSE

# %% [raw]
# file='/home/cccr/roxy/panini/JGRJD_PHD_PART_I/DATA/MSE_calc/20_cr/monthly/MSE_vert_integrated_20CR.nc'
# cdo selname,MSE_vint ${file} hadisst.nc
# cdo ymonmean -selyear,1905/2014 hadisst.nc clim_sst.nc
# cdo sub hadisst.nc clim_sst.nc skt_mon_anomalies_1870-2019.nc
#
# rm hadisst.nc clim_sst.nc  had.nc
#
#
# for i in $(seq 1905 1 2013)
# do
# l=$((i + 1))
# cdo selyear,$i skt_mon_anomalies_1870-2019.nc tempx1.nc
# cdo selmon,11,12 tempx1.nc tempx11.nc
# cdo selyear,$l skt_mon_anomalies_1870-2019.nc tempy1.nc
# cdo selmon,1,2,3,4 tempy1.nc tempy11.nc
#
# cdo mergetime tempx11.nc tempy11.nc jgr1.nc
#
# cdo timmean jgr1.nc mean1_$l.nc
#
# # cdo mergetime mean*.nc mjo_mean$l.nc
#
# rm temp*.nc
# rm jgr*.nc
#
# echo $NUM
#
# done
#
# cdo mergetime mean1*.nc MSE_raw_nov_apr_1905-2014_20CRV2.nc
#
# rm mean*.nc
# rm skt_mon_anomalies_1870-2019.nc
