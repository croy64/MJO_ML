# %%
# !pwd
# Out:
# /home/cccr/supriyo/panini/filtered_data/historical/JGRJD/stacked_lstm_butter_filter

# %% [markdown]
# ## Stacked Long-term Short-term memory network (Stacked-LSTM)

# %% [markdown]
# Written by Abirlal Metya, Panini Dasgupta, Manmeet Singh (19/12/2019)

# %% [markdown]
# import modules

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from keras.models import Sequential
from keras.layers import Dropout,LSTM,Dense
from keras.layers import LeakyReLU


import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime
import hilbert_data1_jgrjd_20CRV33
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Test and Train Splitter:

# %%
x_train,y_train,_ = hilbert_data1_jgrjd_20CRV33.data_hilbert(datetime.datetime(1979,1,1),datetime.datetime(2008,12,31))
# x_test,y_test,_ = hilbert_data1_jgrjd_20CRV33.data_hilbert(datetime.datetime(1974,6,1),datetime.datetime(1978,3,16))
x_test,y_test,_ = hilbert_data1_jgrjd_20CRV33.data_hilbert(datetime.datetime(2009,1,1),datetime.datetime(2015,12,31))

# %%
print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
y_train.head()
# Out:
# (10839, 48) (10839, 1) (2437, 48) (2437, 1)
#                 rmm1
# date
# 1979-04-30 -0.823292
# 1979-05-01 -0.412913
# 1979-05-02  0.021600
# 1979-05-03  0.424877
# 1979-05-04  0.745713

# %% [markdown]
# #### Historical pressure

# %%
x_test3 = hilbert_data1_jgrjd_20CRV33.data_pres(datetime.datetime(1905,1,1),datetime.datetime(2015,12,31))
x_test3.shape
# Out:
# (40423, 48)

# %%
plt.plot(x_test3.iloc[:,0],label = 'total _period')
plt.plot(x_train.iloc[:,0], label = 'train')
plt.plot(x_test.iloc[:,0], label = 'test')
plt.legend()
plt.ylabel('RMM1')
# Out:
# /home/cccr/supriyo/.conda/envs/knp_ai/lib/python3.7/site-packages/pandas/plotting/_matplotlib/converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'RMM1')

# %% [markdown]
# #### scale the data

# %%
from sklearn.preprocessing import MinMaxScaler

sc3 = MinMaxScaler()
sc5 = MinMaxScaler()

sc5.fit(x_test3[:])

test_x3 =  sc5.transform(x_test3[:])
train_x = sc5.transform(x_train[:])
test_x  = sc5.transform(x_test[:])


sc3.fit(y_train[:])

train_y = sc3.transform(y_train)
test_y  = sc3.transform(y_test)

train_x.max(),test_x.max(),test_x3.max(),train_y.max(),test_y.max()
# Out:
# (1.0469156527704322,
#  1.104979549116266,
#  1.0000000000000002,
#  1.0,
#  0.8094679826583451)

# %% [markdown]
# In RNN we have to choose a window. Here we choose first 120 points as predictor and next RMM value as predicted. That means RMM will be fitted using previous 120 time steps's pressure of every point

# %% [markdown]
# #### split the sequence data for training

# %%
def split_sequence(window,x,*args):
    xout  = []
    for i in range(window,len(x)):
        xout.append(x[i-window:i,:])
    
    xout = np.array(xout)
    xout = np.reshape(xout,(xout.shape[0],xout.shape[1],xout.shape[2]))
        
    if np.any(len(args)):
        for y in args:
            yout = []
            for i in range(window,len(y)):
                yout.append(y[i,0])
            yout = np.array(yout)
            yout = yout.reshape(yout.shape[0])
    else:
        yout = [] 
    
    return xout,yout

# %%
window = 120
xtrain , ytrain = split_sequence(window,train_x,train_y)
xtest , ytest = split_sequence(window,test_x,test_y)
xtest3,_ = split_sequence(window, test_x3)

# %% [markdown]
# #### Cut the data according to batch size

# %%
par_b =100 

print(x_test3.shape)
te3_lc = ((len(x_test3)-window)//par_b)*par_b

xtest3 = xtest3[:te3_lc,:,:]
print(xtest3.shape)

x_test3.iloc[window:window+te3_lc,:].index
## THis perid data will be available
# Out:
# (40423, 48)
# (40300, 120, 48)
# DatetimeIndex(['1905-08-28', '1905-08-29', '1905-08-30', '1905-08-31',
#                '1905-09-01', '1905-09-02', '1905-09-03', '1905-09-04',
#                '1905-09-05', '1905-09-06',
#                ...
#                '2015-12-19', '2015-12-20', '2015-12-21', '2015-12-22',
#                '2015-12-23', '2015-12-24', '2015-12-25', '2015-12-26',
#                '2015-12-27', '2015-12-28'],
#               dtype='datetime64[ns]', length=40300, freq=None)

# %%
print(xtrain.shape,ytrain.shape,xtest.shape,ytest.shape)

tr_lc = ((len(x_train)-window)//par_b)*par_b
te_lc =  ((len(x_test)-window)//par_b)*par_b
xtrain = xtrain[:tr_lc,:,:]
ytrain = ytrain[:tr_lc]
xtest = xtest[:te_lc,:,:]
ytest = ytest[:te_lc]

print(xtrain.shape,ytrain.shape,xtest.shape,ytest.shape)
# Out:
# (10719, 120, 48) (10719,) (2317, 120, 48) (2317,)
# (10700, 120, 48) (10700,) (2300, 120, 48) (2300,)

# %% [markdown]
# ### Construct the stacked-LSTM model

# %%
np.random.seed(7)

# %%
batch_size = 50

regressor = Sequential()
regressor.add(LSTM(90, batch_input_shape=(batch_size, xtrain.shape[1], xtrain.shape[2]), stateful=True, return_sequences=True))
regressor.add(Dropout(0.2))
regressor.add(LSTM(90, batch_input_shape=(batch_size, xtrain.shape[1], xtrain.shape[2]), stateful=True, return_sequences=True))
regressor.add(Dropout(0.2))
regressor.add(LSTM(90, batch_input_shape=(batch_size, xtrain.shape[1], xtrain.shape[2]), stateful=True, return_sequences=True))
regressor.add(Dropout(0.2))
regressor.add(LSTM(90, batch_input_shape=(batch_size, xtrain.shape[1], xtrain.shape[2]), stateful=True))
regressor.add(Dropout(0.2))
regressor.add(Dense(1,activation='linear'))
regressor.compile(loss='mae', optimizer='adam')

# %%
regressor.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (50, 120, 90)             50040
# _________________________________________________________________
# dropout_1 (Dropout)          (50, 120, 90)             0
# _________________________________________________________________
# lstm_2 (LSTM)                (50, 120, 90)             65160
# _________________________________________________________________
# dropout_2 (Dropout)          (50, 120, 90)             0
# _________________________________________________________________
# lstm_3 (LSTM)                (50, 120, 90)             65160
# _________________________________________________________________
# dropout_3 (Dropout)          (50, 120, 90)             0
# _________________________________________________________________
# lstm_4 (LSTM)                (50, 90)                  65160
# _________________________________________________________________
# dropout_4 (Dropout)          (50, 90)                  0
# _________________________________________________________________
# dense_1 (Dense)              (50, 1)                   91
# =================================================================
# Total params: 245,611
# Trainable params: 245,611
# Non-trainable params: 0
# _________________________________________________________________

# %% [raw]
# iteration = 5
# for i in range(iteration):
#     print(i)
#     history = regressor.fit(xtrain, ytrain,validation_data= (xtest,ytest), epochs=1, batch_size=batch_size, verbose=1, shuffle=False)
#     regressor.reset_states()

# %%
history = regressor.fit(xtrain, ytrain,validation_data= (xtest,ytest), epochs=20, batch_size=batch_size, verbose=1, shuffle=False)
# Out:
# Train on 10700 samples, validate on 2300 samples
# Epoch 1/20
# 10700/10700 [==============================] - 60s 6ms/step - loss: 0.1129 - val_loss: 0.0782
# Epoch 2/20
# 10700/10700 [==============================] - 55s 5ms/step - loss: 0.0889 - val_loss: 0.0734
# Epoch 3/20
# 10700/10700 [==============================] - 56s 5ms/step - loss: 0.0811 - val_loss: 0.0740
# Epoch 4/20
# 10700/10700 [==============================] - 54s 5ms/step - loss: 0.0768 - val_loss: 0.0805
# Epoch 5/20
# 10700/10700 [==============================] - 55s 5ms/step - loss: 0.0736 - val_loss: 0.0818
# Epoch 6/20
# 10700/10700 [==============================] - 55s 5ms/step - loss: 0.0705 - val_loss: 0.0787
# Epoch 7/20
# 10700/10700 [==============================] - 53s 5ms/step - loss: 0.0696 - val_loss: 0.0737
# Epoch 8/20
# 10700/10700 [==============================] - 52s 5ms/step - loss: 0.0679 - val_loss: 0.0781
# Epoch 9/20
# 10700/10700 [==============================] - 54s 5ms/step - loss: 0.0661 - val_loss: 0.0745
# Epoch 10/20
# 10700/10700 [==============================] - 53s 5ms/step - loss: 0.0660 - val_loss: 0.0739
# Epoch 11/20
# 10700/10700 [==============================] - 53s 5ms/step - loss: 0.0650 - val_loss: 0.0682
# Epoch 12/20
# 10700/10700 [==============================] - 53s 5ms/step - loss: 0.0648 - val_loss: 0.0670
# Epoch 13/20
# 10700/10700 [==============================] - 54s 5ms/step - loss: 0.0642 - val_loss: 0.0629
# Epoch 14/20
# 10700/10700 [==============================] - 54s 5ms/step - loss: 0.0642 - val_loss: 0.0611
# Epoch 15/20
# 10700/10700 [==============================] - 54s 5ms/step - loss: 0.0637 - val_loss: 0.0590
# Epoch 16/20
# 10700/10700 [==============================] - 53s 5ms/step - loss: 0.0633 - val_loss: 0.0646
# Epoch 17/20
# 10700/10700 [==============================] - 54s 5ms/step - loss: 0.0624 - val_loss: 0.0596
# Epoch 18/20
# 10700/10700 [==============================] - 53s 5ms/step - loss: 0.0616 - val_loss: 0.0597
# Epoch 19/20
# 10700/10700 [==============================] - 53s 5ms/step - loss: 0.0619 - val_loss: 0.0599
# Epoch 20/20
# 10700/10700 [==============================] - 53s 5ms/step - loss: 0.0609 - val_loss: 0.0586

# %%
history.history.keys()
# Out:
# dict_keys(['val_loss', 'loss'])

# %%
plt.plot(history.history['loss'],'-*',label ='train')
plt.plot(history.history['val_loss'],'-*',label ='test')
plt.ylabel('MAE')
plt.xlabel('No of Epochs')
plt.legend()
plt.savefig('RMM1_history.png')

# %% [markdown]
# regressor.fit(xtrain,ytrain,epochs=30,batch_size=batch_size)

# %% [markdown]
# Histogram plot over train and test dataset
# To plot histogram real values of the model prediction is required. While model out put is normalized using Min-Max Scalar. So, inverse transform is required before histogrram with ytrain or smooth RMM component

# %% [markdown]
# ##### Predict train dataset:

# %%
predict1   = regressor.predict(xtrain,batch_size=batch_size)
yy_train   = sc3.inverse_transform(predict1)
yy_train   = yy_train/yy_train.std()
train_corr = np.corrcoef(yy_train[:,0],ytrain)[0,1]

print("training shape = ");print(predict1.shape)

fig,ax = plt.subplots(1,2,figsize = (12,4))

ax[0].plot(yy_train[:,0],ytrain,'.')

ax[0].set_title('corr = %f'%train_corr)

bins = np.linspace(-4.0,4.0,41)

ax[1].hist(y_train.rmm1,bins,density=True,alpha=0.5,label='observed')
# plt.hist(rmm1.rmm1,bins=35,density=True,alpha=0.5,label='observed')
ax[1].hist(yy_train,bins,density=True,alpha=0.5,label='modeled');
plt.legend()
# Out:
# training shape =
# (10700, 1)

# %% [markdown]
# ##### Predict test dataset:

# %%
predict2  = regressor.predict(xtest,batch_size=batch_size)
yy_test   = sc3.inverse_transform(predict2)
yy_test   = yy_test/yy_test.std()
test_corr = np.corrcoef(yy_test[:,0],ytest)[0,1]

print("test shape = ");print(predict2.shape)

fig,ax = plt.subplots(1,2,figsize = (12,4))

ax[0].plot(yy_test[:,0],ytest,'.')

ax[0].set_title('corr = %f'%test_corr)

bins = np.linspace(-4.0,4.0,41)


ax[1].hist(y_test.rmm1,bins,density=True,alpha=0.5,label='observed')
# plt.hist(rmm1.rmm1,bins=35,density=True,alpha=0.5,label='observed')
ax[1].hist(yy_test,bins,density=True,alpha=0.5,label='modeled');
plt.legend()
# Out:
# test shape =
# (2300, 1)

# %% [raw]
# dff = pd.read_csv('/home/cccr/supriyo/panini/data/full_data_nn.txt',index_col='date')
# rmm = dff[['rmm1']]
# rmm.index = pd.to_datetime(rmm.index)
# rmm1 = rmm[rmm.index.year >= 1979]
# rmm2 = rmm[rmm.index.year < 1978]

# %% [markdown]
# #### Prediction over long time period (1946-2008)

# %%
predict3 = regressor.predict(xtest3,batch_size=batch_size)
predict3 = sc3.inverse_transform(predict3)
predict3 = predict3/np.std(predict3)

# %% [markdown]
# Check corelation of observed rmm1 and model prediction over 1979-2008 while using pressure from 1946-2008

# %%
rm = len(xtest3)-len(test_x3)+ window
itx = x_test3[window:rm].index ## We are using 120 days running mean as input so first 120 values should be ignored
#As stacked LSTM is used with batch size of 50, so input and output should have timeseries that divided by 50, so we ignored last 148 values for round off 
rmm1_05_15 = pd.DataFrame(predict3,index = itx)

plt.plot(rmm1_05_15.loc[y_train.index,:],y_train,"+")
corr  = np.corrcoef(y_train.values.squeeze(),rmm1_05_15.loc[y_train.index,:].values.squeeze())[0,1]
plt.title('correlation netween oliver and LSTM = %f'%corr)
# Out:
# Text(0.5, 1.0, 'correlation netween oliver and LSTM = 0.876234')

# %%
itx
# Out:
# DatetimeIndex(['1905-08-28', '1905-08-29', '1905-08-30', '1905-08-31',
#                '1905-09-01', '1905-09-02', '1905-09-03', '1905-09-04',
#                '1905-09-05', '1905-09-06',
#                ...
#                '2015-12-19', '2015-12-20', '2015-12-21', '2015-12-22',
#                '2015-12-23', '2015-12-24', '2015-12-25', '2015-12-26',
#                '2015-12-27', '2015-12-28'],
#               dtype='datetime64[ns]', length=40300, freq=None)

# %% [markdown]
# Relation with Oliver Index

# %%
df = pd.read_csv('/home/cccr/supriyo/panini/data/rmm_oliver.csv')
df['date'] = df.year.map(str)+'-'+df.month.map(str)+'-'+df.day.map(str)
df.date = pd.to_datetime(df.date)
df.index = df.date
r1 = df.loc['1906-1-1':'2008-12-31','IHR1'].values
r2 = rmm1_05_15.loc['1906-1-1':'2008-12-31'].values.squeeze()

corr = np.corrcoef(r1,r2)[0,1]

fig,ax = plt.subplots(1,2,figsize = (14,5))
ax[0].scatter(r1,r2)
ax[0].set_title('correlation netween oliver and LSTM = %f'%corr)
bins = np.linspace(-4.0,4.0,41)

ax[1].hist(r1,bins,alpha=0.5,label='lstm')
ax[1].hist(r2,bins,alpha = 0.5,label='oliver')
ax[1].axvline(0.0,color='r')
plt.legend()

# %%
RMM1         = rmm1_05_15*1
RMM1.columns = ['rmm1']
# RMM1.to_csv('rmm1_prediction_05-15_minmax_butter_filt.csv')

# %%
plt.figure(figsize = (20,8))
plt.plot(RMM1.loc[y_test.index][300:600],label = 'predicted LSTM RMM1')
plt.plot(y_test[300:600],'k',label = 'original RMM1')
plt.plot(df.loc[y_test.index,'IHR1'][300:600],label = 'oliver RMM1')
plt.legend()
# Out:
# /home/cccr/supriyo/.conda/envs/knp_ai/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-0a8362173588> in <module>
#       2 plt.plot(RMM1.loc[y_test.index][300:600],label = 'predicted LSTM RMM1')
#       3 plt.plot(y_test[300:600],'k',label = 'original RMM1')
# ----> 4 plt.plot(df.loc[y_test.index,'IHR1'][300:600],label = 'oliver RMM1')
#       5 plt.legend()
#
# ~/.conda/envs/knp_ai/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1416                 except (KeyError, IndexError, AttributeError):
#    1417                     pass
# -> 1418             return self._getitem_tuple(key)
#    1419         else:
#    1420             # we by definition only have the 0th axis
#
# ~/.conda/envs/knp_ai/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#     803     def _getitem_tuple(self, tup):
#     804         try:
# --> 805             return self._getitem_lowerdim(tup)
#     806         except IndexingError:
#     807             pass
#
# ~/.conda/envs/knp_ai/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#     959                     return section
#     960                 # This is an elided recursive call to iloc/loc/etc'
# --> 961                 return getattr(section, self.name)[new_key]
#     962
#     963         raise IndexingError("not applicable")
#
# ~/.conda/envs/knp_ai/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1422
#    1423             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1424             return self._getitem_axis(maybe_callable, axis=axis)
#    1425
#    1426     def _is_scalar_access(self, key: Tuple):
#
# ~/.conda/envs/knp_ai/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1837                     raise ValueError("Cannot index with multidimensional key")
#    1838
# -> 1839                 return self._getitem_iterable(key, axis=axis)
#    1840
#    1841             # nested tuple slicing
#
# ~/.conda/envs/knp_ai/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
#    1131         else:
#    1132             # A collection of keys
# -> 1133             keyarr, indexer = self._get_listlike_indexer(key, axis, raise_missing=False)
#    1134             return self.obj._reindex_with_indexers(
#    1135                 {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# ~/.conda/envs/knp_ai/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1090
#    1091         self._validate_read_indexer(
# -> 1092             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1093         )
#    1094         return keyarr, indexer
#
# ~/.conda/envs/knp_ai/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1175                 raise KeyError(
#    1176                     "None of [{key}] are in the [{axis}]".format(
# -> 1177                         key=key, axis=self.obj._get_axis_name(axis)
#    1178                     )
#    1179                 )
#
# KeyError: "None of [DatetimeIndex(['2009-04-30', '2009-05-01', '2009-05-02', '2009-05-03',\n               '2009-05-04', '2009-05-05', '2009-05-06', '2009-05-07',\n               '2009-05-08', '2009-05-09',\n               ...\n               '2015-12-22', '2015-12-23', '2015-12-24', '2015-12-25',\n               '2015-12-26', '2015-12-27', '2015-12-28', '2015-12-29',\n               '2015-12-30', '2015-12-31'],\n              dtype='datetime64[ns]', name='date', length=2437, freq=None)] are in the [index]"
